# %% [markdown]
# #### 데이터 전처리 기초

# %% [markdown]
# * missingno: 결측 데이터 검색
# * sklearn.impute: 결측 데이터 대체
# * patsy: 데이터 선택, 변환, 추가, 스케일링
# * sklearn.preprocessing: 스케일링, 변환

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.impute import SimpleImputer

from io import StringIO

csv_data = StringIO("""
x1,x2,x3,x4,x5
1,0.1,"1",2019-01-01,A
2,,,2019-01-02,B
3,,"3",2019-01-03,C
,0.4,"4",2019-01-04,A
5,0.5,"5",2019-01-05,B
,,,2019-01-06,C
7,0.7,"7",,A
8,0.8,"8",2019-01-08,B
9,0.9,,2019-01-09,C
""")

df = pd.read_csv(csv_data, dtype={"x1": pd.Int64Dtype()}, parse_dates=[3])
df
# Out:
#      x1   x2   x3         x4 x5
# 0     1  0.1  1.0 2019-01-01  A
# 1     2  NaN  NaN 2019-01-02  B
# 2     3  NaN  3.0 2019-01-03  C
# 3  <NA>  0.4  4.0 2019-01-04  A
# 4     5  0.5  5.0 2019-01-05  B
# 5  <NA>  NaN  NaN 2019-01-06  C
# 6     7  0.7  7.0        NaT  A
# 7     8  0.8  8.0 2019-01-08  B
# 8     9  0.9  NaN 2019-01-09  C

# %%
df.isnull()
df.isna().sum()
# Out:
# x1    2
# x2    3
# x3    3
# x4    1
# x5    0
# dtype: int64

# %%
msno.matrix(df)
plt.show()

# %%
msno.bar(df)
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
msno.matrix(titanic)
plt.show()

# %%
msno.bar(titanic)
plt.show()

# %% [markdown]
# 결측된 데이터 처리 방법
# 1. 결측된 데이터가 너무 많은 경우 해당 데이터 열 전체를 삭제한다.
# 2. 결측된 데이터가 일부인 경우 그럴듯한 값으로 대체한다.

# %%
msno.matrix(df)
plt.show()

# %%
df
# Out:
#      x1   x2   x3         x4 x5
# 0     1  0.1  1.0 2019-01-01  A
# 1     2  NaN  NaN 2019-01-02  B
# 2     3  NaN  3.0 2019-01-03  C
# 3  <NA>  0.4  4.0 2019-01-04  A
# 4     5  0.5  5.0 2019-01-05  B
# 5  <NA>  NaN  NaN 2019-01-06  C
# 6     7  0.7  7.0        NaT  A
# 7     8  0.8  8.0 2019-01-08  B
# 8     9  0.9  NaN 2019-01-09  C

# %% [markdown]
# 결측인 행 제거

# %%
df.dropna()
# Out:
#    x1   x2   x3         x4 x5
# 0   1  0.1  1.0 2019-01-01  A
# 4   5  0.5  5.0 2019-01-05  B
# 7   8  0.8  8.0 2019-01-08  B

# %% [markdown]
# 결측인 열 제거

# %%
df.dropna(axis=1)
# Out:
#   x5
# 0  A
# 1  B
# 2  C
# 3  A
# 4  B
# 5  C
# 6  A
# 7  B
# 8  C

# %% [markdown]
# 특정 갯수 이상의 비결측 데이터가 있는 행 또는 열만 남긴다.

# %%
df.dropna(thresh=7, axis=1)
# Out:
#      x1         x4 x5
# 0     1 2019-01-01  A
# 1     2 2019-01-02  B
# 2     3 2019-01-03  C
# 3  <NA> 2019-01-04  A
# 4     5 2019-01-05  B
# 5  <NA> 2019-01-06  C
# 6     7        NaT  A
# 7     8 2019-01-08  B
# 8     9 2019-01-09  C

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 데이터가 절반 이상 없는 열 삭제
titanic.dropna(thresh=round(len(titanic)*0.5), axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# 결측 데이터를 대체할 경우 해당 열의 비결측 데이터의 평균값 혹은 중앙값 등으로 대체
#
# SimpleImputer를 이용하여 strategy 인수를 통해 'mean', 'median', 'most_frequent'로 대체값 사용
#
# * 데이터가 실수인 연속값인 경우
#
#     값의 분포가 대칭적이면 평균
#
#     값의 분포가 비대칭적이면 중앙값
#
# * 데이터가 범주값이거나 정수값인 경우
#
#     최빈값 사용

# %%
df.astype('float')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11876\3729797577.py in <module>
# ----> 1 df.astype('float')
#
# c:\Users\ghckd\anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# c:\Users\ghckd\anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
df['x4'] = df['x4'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11876\1313561135.py in <module>
# ----> 1 df['x4'] = df['x4'].astype('float64')
#
# c:\Users\ghckd\anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# c:\Users\ghckd\anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
imputer = SimpleImputer(strategy="most_frequent")
imputer.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11876\1602284374.py in <module>
#       1 imputer = SimpleImputer(strategy="most_frequent")
# ----> 2 imputer.fit_transform(df)
#
# c:\Users\ghckd\anaconda\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# c:\Users\ghckd\anaconda\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     317             Fitted estimator.
#     318         """
# --> 319         X = self._validate_input(X, in_fit=True)
#     320
#     321         # default fill_value is 0 for numerical input and "missing_value"
# ...

# %%
imputer = SimpleImputer(strategy="most_frequent")
df = df.astype(float)
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26132\101257694.py in <module>
#       1 imputer = SimpleImputer(strategy="most_frequent")
# ----> 2 df = df.astype(float)
#       3 df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
#       4 df
#
# c:\Users\ghckd\anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# c:\Users\ghckd\anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...
